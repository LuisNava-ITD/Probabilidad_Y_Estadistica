# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisNava-ITD/Probabilidad_Y_Estadistica/blob/main/Probabilidad_U2_programa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilida y Estadistica/ Unidad2
#
# ##Alumno:
# ###Luis Eduardo Nava Estupiñan
# ##Docente:
# ###Jose Gabriel Rodriguez Rivas

# %%
import math as mt
from itertools import permutations
from itertools import product
import numpy as np


numeros = ["1", "2", "3", "4", "5", "6", "7", "8", "9"]
n = len(numeros)
e = 4

Pr  = mt.factorial(n)/mt.factorial(n-e)
print("Existen", Pr, "posinles permutaciones sin repeticion del total de ",
      n , "nombre", "en grupos de ", e, "en ", e)

print("aqui las permutaciones")
permutaciones_numeros = list(permutations(numeros, e))

for permutacion in permutaciones_numeros:
    print(permutacion)
# Out:
# Existen 3024.0 posinles permutaciones sin repeticion del total de  9 nombre en grupos de  4 en  4
# aqui las permutaciones
# ('1', '2', '3', '4')
# ('1', '2', '3', '5')
# ('1', '2', '3', '6')
# ('1', '2', '3', '7')
# ('1', '2', '3', '8')
# ('1', '2', '3', '9')
# ('1', '2', '4', '3')
# ('1', '2', '4', '5')
# ('1', '2', '4', '6')
# ('1', '2', '4', '7')
# ('1', '2', '4', '8')
# ('1', '2', '4', '9')
# ('1', '2', '5', '3')
# ('1', '2', '5', '4')
# ('1', '2', '5', '6')
# ('1', '2', '5', '7')
# ('1', '2', '5', '8')
# ('1', '2', '5', '9')
# ('1', '2', '6', '3')
# ('1', '2', '6', '4')
# ('1', '2', '6', '5')
# ('1', '2', '6', '7')
# ('1', '2', '6', '8')
# ('1', '2', '6', '9')
# ('1', '2', '7', '3')
# ('1', '2', '7', '4')
# ('1', '2', '7', '5')
# ('1', '2', '7', '6')
# ('1', '2', '7', '8')
# ('1', '2', '7', '9')
# ('1', '2', '8', '3')
# ('1', '2', '8', '4')
# ('1', '2', '8', '5')
# ('1', '2', '8', '6')
# ('1', '2', '8', '7')
# ('1', '2', '8', '9')
# ('1', '2', '9', '3')
# ('1', '2', '9', '4')
# ...
